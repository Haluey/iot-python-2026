# %% [markdown]
# ## 데이터 분석 기초
#
# ### WordCloud
#
# - 말구름. 단어를 구름형태로 보여주는 데이터 분석 중 하나
#
# #### 설치
#
# ```bash
# !pip install wordcloud
# ```

# %%
# !pip install wordcloud
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# wordcloud 라이브러리 로드
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = '''python is my favortie programming langauge, data analysis. python ai ai ai
          deep learning, machine learning, contemporary ai skill'''

wc = WordCloud().generate(text)

# %%
plt.imshow(wc)  # 이미지로 보여줌
plt.axis('off') # 차트의 x, y축 눈금, 레이블을 의미하는 객체
plt.show()

# %%
# C++, C#의 특수문자를 제대로 인식 못함
text = '데이터 분석 파이썬 인공지능 인공지능 인공지능 데이터 파이썬 인공지능 C++ Java 인공지능 C#'

wc = WordCloud(
    font_path='C:/Windows/Fonts/NanumGothicExtraBold.ttf',
    background_color='azure',
    colormap='plasma' # viridis, plasma, inferno, cool
    ).generate(text)

plt.imshow(wc)  # 이미지로 보여줌
plt.axis('off') # 차트의 x, y축 눈금, 레이블을 의미하는 객체
plt.show()
