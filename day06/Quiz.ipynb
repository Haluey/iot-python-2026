# %% [markdown]
# #### 260402 IoT개발자 데이터분석 퀴즈

# %%
# 1번
nums = [1, 2, 3]
nums.append(4)
print(len(nums))
# Out:
# 4

# %%
# 2번
def add(a, b):
    return a + b

# %%
'''
3번 파일 입출력 시 `with open(...)` 구문을 사용하는 가장 큰 이유는 무엇인가요?
    - close()를 명시적으로 호출하지 않아도 되기 때문에
'''

# %%
'''
4번 데이터 전처리 과정에서 특정 컬럼의 결측치(NULL)가 전체 데이터의 40% 이상일 때,
    소스 자료에서 권장하는 처리 방법은 무엇입니까?
    - 해당 컬럼을 분석에서 제외시킨다
'''

# %%
'''
5번 파이썬 클래스 내부에서 정의된 메서드의 첫 번째 파라미터로 반드시 사용해야 하며,
    C++의 `this` 포인터와 유사한 역할을 하는 것은 무엇입니까?
    - self
'''

# %%
'''
6번 파이썬에서 여러 파일 중 프로그램의 시작점(Entry Point)을 확인하기 위해 
    사용하는 특수 변수는 무엇입니까?
    - __name__
'''

# %%
# 7번
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
'''
8번 데이터 전처리 과정 중 '문자열로 된 범주형 데이터(예: male, female)'를 분석이 가능하도록 
    수치 데이터로 변환하는 과정을 무엇이라고 합니까?
    - 인코딩(Encoding)
'''

# %%
'''
9번 두 데이터 간의 관계를 나타내는 상관계수에 대한 설명으로 옳은 것은?
    - 값의 범위는 -1에서 1사이이며, 0은 관계 없음을 뜻한다
'''

# %%
'''
10번 다음 중 파이썬의 패키지 관리 도구로, 
    외부 라이브러리를 설치할 때 사용하는 명령어는 무엇입니까?
    - pip
'''
